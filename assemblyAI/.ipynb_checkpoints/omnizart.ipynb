# %%
# resolved automatically.
# !pip install numpy Cython
# Install Omnizart
# !pip install omnizart
# Then download the checkpoints
# !omnizart download-checkpoints
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# ...
#   Using cached omnizart-0.5.0-py3-none-any.whl (10.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 65.8 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached librosa-0.8.1-py3-none-any.whl (203 kB)
# ...
#   Using cached spleeter-2.3.2-py3-none-any.whl (51 kB)
# ...
#   Using cached mir_eval-0.6.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.4/454.4 MB 3.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 31.6 MB/s eta 0:00:00
# ...
#   Using cached pyFluidSynth-1.3.2-py3-none-any.whl (19 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 29.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 19.6 MB/s eta 0:00:00
# ...

# %%
# !omnizart music transcibe
